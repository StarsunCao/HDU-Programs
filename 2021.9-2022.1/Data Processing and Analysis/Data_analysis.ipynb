# %%
#Import Python Libraries
import numpy as np
import scipy as sp
import pandas as pd

# %%
df = pd.read_csv('Salaries.csv', delimiter=',')

# %%
df.head()
# Out:
#    Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0           1      Prof          B             19           18  Male  139750
# 1           2      Prof          B             20           16  Male  173200
# 2           3  AsstProf          B              4            3  Male   79750
# 3           4      Prof          B             45           39  Male  115000
# 4           5      Prof          B             40           41  Male  141500

# %%
df.tail()
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 392         393      Prof          A             33           30  Male  103106
# 393         394      Prof          A             31           19  Male  150564
# 394         395      Prof          A             42           25  Male  101738
# 395         396      Prof          A             25           15  Male   95329
# 396         397  AsstProf          A              8            4  Male   81035

# %%
df.sample(10)
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service   sex  \
# 285         286  AssocProf          A             49           49  Male
# 128         129       Prof          A             32           30  Male
# 97           98       Prof          B             13            7  Male
# 239         240       Prof          A             19            6  Male
# 265         266       Prof          A             36           30  Male
# 169         170       Prof          B             25           18  Male
# 333         334       Prof          B             33           19  Male
# 351         352       Prof          B             38           38  Male
# 263         264       Prof          A             31           31  Male
# 0             1       Prof          B             19           18  Male
#
#      salary
# 285   81800
# 128  113278
# 97   129676
# 239   96200
# 265  134800
# 169  181257
# 333  145098
# 351   93519
# 263  126000
# 0    139750

# %%
df.head(10)
# Out:
#    Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0           1       Prof          B             19           18    Male
# 1           2       Prof          B             20           16    Male
# 2           3   AsstProf          B              4            3    Male
# 3           4       Prof          B             45           39    Male
# 4           5       Prof          B             40           41    Male
# 5           6  AssocProf          B              6            6    Male
# 6           7       Prof          B             30           23    Male
# 7           8       Prof          B             45           45    Male
# 8           9       Prof          B             21           20    Male
# 9          10       Prof          B             18           18  Female
#
#    salary
# 0  139750
# 1  173200
# 2   79750
# 3  115000
# 4  141500
# 5   97000
# 6  175000
# 7  147765
# 8  119250
# 9  129000

# %%
df['salary'].dtype
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# rank             object
# discipline       object
# yrs.since.phd     int64
# yrs.service       int64
# sex              object
# salary            int64
# dtype: object

# %%
df.size
# Out:
# 2779

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'rank', 'discipline', 'yrs.since.phd', 'yrs.service',
#        'sex', 'salary'],
#       dtype='object')

# %%
num_rows = df.shape[0] 
print('Number of Rows in DataFrame :',num_rows)
# Out:
# Number of Rows in DataFrame : 397

# %%
df['salary'].max()
# Out:
# 231545

# %%
df['salary'].sum()
# Out:
# 45141464

# %%
df.head(50).mean()
# Out:
# Unnamed: 0           25.50
# yrs.since.phd        20.92
# yrs.service          16.22
# salary           112625.64
# dtype: float64

# %%
df.describe()
# Out:
#        Unnamed: 0  yrs.since.phd  yrs.service         salary
# count  397.000000     397.000000   397.000000     397.000000
# mean   199.000000      22.314861    17.614610  113706.458438
# std    114.748275      12.887003    13.006024   30289.038695
# min      1.000000       1.000000     0.000000   57800.000000
# 25%    100.000000      12.000000     7.000000   91000.000000
# 50%    199.000000      21.000000    16.000000  107300.000000
# 75%    298.000000      32.000000    27.000000  134185.000000
# max    397.000000      56.000000    60.000000  231545.000000

# %%
num_rows = df.count()[0] 
print('Number of Rows in DataFrame :',num_rows)
# Out:
# Number of Rows in DataFrame : 397

# %%
mean_df = df['salary'].mean()
print(mean_df)
# Out:
# 113706.45843828715

# %%
df_rank = df.groupby(['rank'])
df_rank.mean()
# Out:
#            Unnamed: 0  yrs.since.phd  yrs.service         salary
# rank
# AssocProf  179.828125      15.453125    11.953125   93876.437500
# AsstProf   169.761194       5.104478     2.373134   80775.985075
# Prof       210.977444      28.300752    22.815789  126772.109023

# %%
df.groupby('rank')[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   93876.437500
# AsstProf    80775.985075
# Prof       126772.109023

# %%
df.groupby(['rank'], sort=False)[['salary']].mean()
# Out:
#                   salary
# rank
# Prof       126772.109023
# AsstProf    80775.985075
# AssocProf   93876.437500

# %%
df_sub = df[ df['salary'] > 120000 ]
print(df_sub)
# Out:
#      Unnamed: 0  rank discipline  yrs.since.phd  yrs.service     sex  salary
# 0             1  Prof          B             19           18    Male  139750
# 1             2  Prof          B             20           16    Male  173200
# 4             5  Prof          B             40           41    Male  141500
# 6             7  Prof          B             30           23    Male  175000
# 7             8  Prof          B             45           45    Male  147765
# 9            10  Prof          B             18           18  Female  129000
# 18           19  Prof          A             37           23    Male  124750
# 19           20  Prof          A             39           36  Female  137000
# 26           27  Prof          A             35           23    Male  134885
# 30           31  Prof          B             20            4    Male  132261
# 36           37  Prof          B             22           21    Male  155750
# ...

# %%
df_f = df[ df['sex'] == 'Female' ]
df_f.head()
# Out:
#     Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 9           10       Prof          B             18           18  Female
# 19          20       Prof          A             39           36  Female
# 24          25  AssocProf          A             13            8  Female
# 34          35   AsstProf          B              4            2  Female
# 35          36   AsstProf          B              5            0  Female
#
#     salary
# 9   129000
# 19  137000
# 24   74830
# 34   80225
# 35   77000

# %%
df['salary'].head()
# Out:
# 0    139750
# 1    173200
# 2     79750
# 3    115000
# 4    141500
# Name: salary, dtype: int64

# %%
df[['rank','salary']].head()
# Out:
#        rank  salary
# 0      Prof  139750
# 1      Prof  173200
# 2  AsstProf   79750
# 3      Prof  115000
# 4      Prof  141500

# %%
df[10:20]
# Out:
#     Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 10          11  AssocProf          B             12            8    Male
# 11          12   AsstProf          B              7            2    Male
# 12          13   AsstProf          B              1            1    Male
# 13          14   AsstProf          B              2            0    Male
# 14          15       Prof          B             20           18    Male
# 15          16       Prof          B             12            3    Male
# 16          17       Prof          B             19           20    Male
# 17          18       Prof          A             38           34    Male
# 18          19       Prof          A             37           23    Male
# 19          20       Prof          A             39           36  Female
#
#     salary
# 10  119800
# 11   79800
# 12   77700
# 13   78000
# 14  104800
# 15  117150
# 16  101000
# 17  103450
# 18  124750
# 19  137000

# %%
df_sub.loc[10:20,['rank','sex','salary']]
# Out:
#     rank     sex  salary
# 18  Prof    Male  124750
# 19  Prof  Female  137000

# %%
df_sub.iloc[10:20,[0, 3, 4, 5]]
# Out:
#     Unnamed: 0  yrs.since.phd  yrs.service     sex
# 36          37             22           21    Male
# 38          39             41           31    Male
# 40          41             23            2    Male
# 43          44             38           38    Male
# 47          48             23           19  Female
# 48          49             25           25  Female
# 50          51             28           28    Male
# 70          71             17            2    Male
# 71          72             45           45    Male
# 76          77             17            3    Male

# %%
df_sorted = df.sort_values( by ='yrs.service')
df_sorted.head()
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service     sex  \
# 154         155  AsstProf          B              4            0    Male
# 127         128  AsstProf          A              2            0  Female
# 164         165  AsstProf          B              1            0    Male
# 28           29  AsstProf          B             11            0    Male
# 287         288  AsstProf          A              2            0    Male
#
#      salary
# 154   92000
# 127   72500
# 164   88795
# 28    77000
# 287   85000

# %%
df_sorted = df.sort_values( by =['yrs.service', 'salary'])
df_sorted.head(10)
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service     sex  \
# 127         128  AsstProf          A              2            0  Female
# 308         309  AsstProf          A              5            0    Male
# 28           29  AsstProf          B             11            0    Male
# 35           36  AsstProf          B              5            0  Female
# 13           14  AsstProf          B              2            0    Male
# 95           96  AsstProf          B              4            0    Male
# 287         288  AsstProf          A              2            0    Male
# 157         158  AsstProf          B              1            0    Male
# 164         165  AsstProf          B              1            0    Male
# 154         155  AsstProf          B              4            0    Male
#
#      salary
# 127   72500
# 308   74000
# 28    77000
# 35    77000
# 13    78000
# 95    84000
# 287   85000
# 157   88000
# 164   88795
# 154   92000

# %%
titanic = pd.read_csv('Titanic.csv', delimiter=',', index_col='PassengerId')

# %%
titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
titanic[titanic.isnull().any(axis=1)].head()
# Out:
#              Survived  Pclass                            Name     Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris    male  22.0
# 3                   1       3          Heikkinen, Miss. Laina  female  26.0
# 5                   0       3        Allen, Mr. William Henry    male  35.0
# 6                   0       3                Moran, Mr. James    male   NaN
# 8                   0       3  Palsson, Master. Gosta Leonard    male   2.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 5                0      0            373450   8.0500   NaN        S
# 6                0      0            330877   8.4583   NaN        Q
# 8                3      1            349909  21.0750   NaN        S

# %%
titanic.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
titanic[['Age','Fare']].agg(['min','mean','max'])
# Out:
#             Age        Fare
# min    0.420000    0.000000
# mean  29.699118   32.204208
# max   80.000000  512.329200
